# %% [markdown]
# # <span style='background :yellow' >Bank Customer Churn Data Analysis and Visualization
# # Analysis Report:
# ## 1. Customers and their Gender
# ![Screenshot_1.png](attachment:7040fa3d-40db-4e27-a434-80feb1a3b5f8.png)
# ### Assumptions:
# - Every 5 out of 1 customer has been churned
# - Almost 55% customers are Male, rest Female
# - Every 4 out of 1 female customer has been churned
# - Churn rate lower in Male comparison to female, every 6 out of 1 male customer has been churned.

# %% [markdown]
# ## 2. Churned Customer’s Age and Gender
# ![Screenshot_2.png](attachment:de8bca30-ef97-4f8b-a8fc-c669868d9eb2.png)
# ### Assumptions:
# - In above left graph shows as age increasing probability of being churned also increasing after 56, age increasing where churn probability decreasing.
# - In right graph it shows there are high no of customers who has been churned were age between 35-55.

# %% [markdown]
# ## 3. Customers Region, Gender and Churn History
# ![Screenshot_3.png](attachment:3d4fb447-4323-4a94-b0e3-effa7b9e2bdf.png)
# ### Assumptions:
# - In above left bar graph, we can clearly see on the basis of region churn rate is high in France and Germany.
# - In middle pie chart we can see 50% customers are from France only, where 25% from Germany and 25% from Spain.
# - Need to focus those customers are from France and Germany.

# %% [markdown]
# ## 4. Customers and Products usage
# ![Screenshot_4.png](attachment:3a7459ea-f5a7-445d-b765-c98fe2420df3.png)
# ![Screenshot_6.png](attachment:8c4be559-fc84-4e4c-abd3-9caae406f658.png)
# ### Assumptions:
# - On the basis of products usage highest churn rate is 100% those are using 4 products, although only 0.6% of total customers used 4 products. Bank strictly stop giving 4 products to the customers to reduce churn rate.
# - Almost 83% churn rate in which who are using 3 products, although the no of customers is very less only 2.6% of total.
# - Those are using 1 product; churn rate is 27.7%, 50.8% of total customers usage 1 product. Something going wrong with this product need attention.
# - Almost 46% of total customers using 2 products, and the churn rate is 7.6%.

# %% [markdown]
# ## 5. Customer has a Credit Card and their Credit Score
# ![Screenshot_7.png](attachment:701d39dc-99e1-47d6-9d1e-3299424cc002.png)
#
# ### Assumptions:
# - Over 70% Churned customers had a credit card, it’s means they might be not satisfied with credit card service after using, other reason this could be to leave.
# - Credit Score is likely same of both who have churned and who have retained.
# - Also, Credit Score almost same of both male and female

# %% [markdown]
# ## 6. Tenure of Customers and their churn rate
# ![Screenshot_8.png](attachment:4911ed75-ab22-43fb-b57a-8f7eecd1993b.png)
# ### Assumptions:
# - We can see in left graph, there is no relation with tenure and churned customers.

# %% [markdown]
# ## 7. Active Rate of Churned Customers vs Retained Customers
# ![Screenshot_9.png](attachment:3dc4c08d-ef06-4296-a4aa-b43c9805c627.png)
# ### Assumptions:
# - Inactive member’s exit rate is higher than active
# - Make strategy for inactive retained members to become active member, churn rate definitely will reduce.

# %% [markdown]
# ## 8. Relation Between Balance of Customers and Age
# ![Screenshot_10.png](attachment:a52cbb9d-ed36-4201-812e-7ffb093d9c45.png)
# ### Assumptions:
# - Many customers are those who’s balance is zero. Although we don’t have any time related info in data to analyse balance record
# - Here we can see in the middle of chart density is high, so we say from age 25-60 has a maintained balance history.

# %% [markdown]
# ## 9. Balance vs Estimated Salary
# ![Screenshot_11.png](attachment:73c9fbb2-0c4c-4bcf-bd79-3f19b451ca46.png)
# ### Assumptions:
# - Many customers estimated salary is high but balance is zero, they might be moved to another bank or they may have money problem.

# %% [markdown]
# # Strategy to Reduce Churn Rate:
# 1. Focus on those customer’s age between 35-55 in terms of age
# 2. Focus on female customers rather than men
# 3. Bank need to stop giving more than 2 products to customers as churn rate very high in more than 2 products
# 4. Make offers for the retained inactive members to make them active
# 5. Talk to those customers having high estimated salary but zero balance.
# 6. Need more attention to the customers belong from France and Germany, especially on Germany.
